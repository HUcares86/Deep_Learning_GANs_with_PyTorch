# %%
#!pip install jovian --upgrade -q

# %%
import torch

# %%
# Number
t1 = torch.tensor(4.)
t1
# Out:
# tensor(4.)

# %%
t1.dtype
# Out:
# torch.float32

# %%
# Vector
t2 = torch.tensor([1., 2, 3, 4])
t2
# Out:
# tensor([1., 2., 3., 4.])

# %%
# Matrix
t3 = torch.tensor([[5., 6], 
                   [7, 8], 
                   [9, 10]])
t3
# Out:
# tensor([[ 5.,  6.],
#         [ 7.,  8.],
#         [ 9., 10.]])

# %%
# 3-dimensional array
t4 = torch.tensor([
    [[11, 12, 13], 
     [13, 14, 15]], 
    [[15, 16, 17], 
     [17, 18, 19.]]])
t4
# Out:
# tensor([[[11., 12., 13.],
#          [13., 14., 15.]],
#
#         [[15., 16., 17.],
#          [17., 18., 19.]]])

# %%
print(t1)
t1.shape
# Out:
# tensor(4.)
# torch.Size([])

# %%
print(t2)
t2.shape
# Out:
# tensor([1., 2., 3., 4.])
# torch.Size([4])

# %%
print(t3)
t3.shape
# Out:
# tensor([[ 5.,  6.],
#         [ 7.,  8.],
#         [ 9., 10.]])
# torch.Size([3, 2])

# %%
print(t4)
t4.shape
# Out:
# tensor([[[11., 12., 13.],
#          [13., 14., 15.]],
#
#         [[15., 16., 17.],
#          [17., 18., 19.]]])
# torch.Size([2, 2, 3])

# %%
# Create tensors.
x = torch.tensor(3.)
w = torch.tensor(4., requires_grad=True)
b = torch.tensor(5., requires_grad=True)
x, w, b
# Out:
# (tensor(3.), tensor(4., requires_grad=True), tensor(5., requires_grad=True))

# %%
# Arithmetic operations
y = w * x + b
y
# Out:
# tensor(17., grad_fn=<AddBackward0>)

# %%
# Compute derivatives
y.backward()

# %%
# Display gradients
print('dy/dx:', x.grad)
print('dy/dw:', w.grad)
print('dy/db:', b.grad)
# Out:
# dy/dx: None
# dy/dw: tensor(3.)
# dy/db: tensor(1.)

# %% [markdown]
# Tensor functions

# %%
# Create a tensor with a fixed value for every element
t6 = torch.full((3, 2), 42)
t6
# Out:
# tensor([[42, 42],
#         [42, 42],
#         [42, 42]])

# %%
# Concatenate two tensors with compatible shapes
t7 = torch.cat((t3, t6))
t7
# Out:
# tensor([[ 5.,  6.],
#         [ 7.,  8.],
#         [ 9., 10.],
#         [42., 42.],
#         [42., 42.],
#         [42., 42.]])

# %%
# Compute the sin of each element
t8 = torch.sin(t7)
t8
# Out:
# tensor([[-0.9589, -0.2794],
#         [ 0.6570,  0.9894],
#         [ 0.4121, -0.5440],
#         [-0.9165, -0.9165],
#         [-0.9165, -0.9165],
#         [-0.9165, -0.9165]])

# %%
# Change the shape of a tensor
t9 = t8.reshape(3, 2, 2)
t9
# Out:
# tensor([[[-0.9589, -0.2794],
#          [ 0.6570,  0.9894]],
#
#         [[ 0.4121, -0.5440],
#          [-0.9165, -0.9165]],
#
#         [[-0.9165, -0.9165],
#          [-0.9165, -0.9165]]])

# %% [markdown]
# Interoperability with Numpy

# %%
import numpy as np

x = np.array([[1, 2], [3, 4.]])
x
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
# Convert the numpy array to a torch tensor.
y = torch.from_numpy(x)
y
# Out:
# tensor([[1., 2.],
#         [3., 4.]], dtype=torch.float64)

# %%
x.dtype, y.dtype
# Out:
# (dtype('float64'), torch.float64)

# %%
# Convert a torch tensor to a numpy array
z = y.numpy()
z
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %% [markdown]
# Save and upload your notebook

# %%
#!pip install jovian --upgrade --quiet

# %%
#import jovian

# %%
j#ovian.commit(project='01-pytorch-basics')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-f6d3fce89423> in <module>
# ----> 1 j#ovian.commit(project='01-pytorch-basics')
#
# NameError: name 'j' is not defined

# %% [markdown]
# # 新增區段
