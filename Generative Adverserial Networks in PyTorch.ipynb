# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
# <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models
# * Commit to Jovian.ml

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([5, 5, 1, 4, 4, 8, 8, 1, 9, 9, 8, 4, 2, 4, 0, 1, 0, 7, 9, 6, 9, 5, 9, 7,
#         6, 5, 0, 4, 2, 5, 0, 3, 4, 7, 6, 9, 5, 9, 8, 2, 4, 3, 7, 6, 4, 4, 1, 7,
#         7, 6, 4, 1, 2, 6, 8, 4, 8, 4, 4, 9, 5, 2, 6, 2, 1, 8, 1, 1, 6, 6, 5, 9,
#         1, 5, 4, 2, 3, 6, 4, 9, 2, 3, 4, 3, 3, 6, 7, 3, 4, 2, 9, 2, 1, 0, 5, 8,
#         3, 8, 8, 4])

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())
# detach() all i want is the value and not the data of the process

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
criterion = nn.BCELoss()

d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    # real photos are label 1, fake are 0
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images) # feed image into discriminator
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)  # generate fake images
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device) # we use ones to trick the discriminator
    g_loss = criterion(D(fake_images), labels)
    # we want to fool the discriminator

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os
# save sample images
sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# from IPython.display import Image
# from torchvision.utils import save_image
#
# # Save some real images
# for images, _ in data_loader:
#     images = images.reshape(images.size(0), 1, 28, 28)
#     save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
#     break
#
# Image(os.path.join(sample_dir, 'real_images.png'))

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0444, g_loss: 4.1348, D(x): 0.99, D(G(z)): 0.03
# Epoch [0/300], Step [400/600], d_loss: 0.0769, g_loss: 5.0463, D(x): 0.97, D(G(z)): 0.04
# Epoch [0/300], Step [600/600], d_loss: 0.0327, g_loss: 4.8942, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0545, g_loss: 4.6918, D(x): 0.99, D(G(z)): 0.04
# Epoch [1/300], Step [400/600], d_loss: 0.2035, g_loss: 4.0213, D(x): 0.92, D(G(z)): 0.04
# Epoch [1/300], Step [600/600], d_loss: 0.0904, g_loss: 4.8336, D(x): 0.99, D(G(z)): 0.08
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.9301, g_loss: 3.0485, D(x): 0.78, D(G(z)): 0.24
# Epoch [2/300], Step [400/600], d_loss: 0.6107, g_loss: 3.6075, D(x): 0.85, D(G(z)): 0.24
# Epoch [2/300], Step [600/600], d_loss: 0.4626, g_loss: 3.9188, D(x): 0.83, D(G(z)): 0.13
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.5763, g_loss: 2.8992, D(x): 0.82, D(G(z)): 0.14
# Epoch [3/300], Step [400/600], d_loss: 1.0305, g_loss: 2.6755, D(x): 0.84, D(G(z)): 0.38
# Epoch [3/300], Step [600/600], d_loss: 0.9134, g_loss: 2.3803, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.6857, g_loss: 2.9681, D(x): 0.80, D(G(z)): 0.19
# Epoch [4/300], Step [400/600], d_loss: 0.4505, g_loss: 2.6834, D(x): 0.86, D(G(z)): 0.13
# Epoch [4/300], Step [600/600], d_loss: 0.4939, g_loss: 2.4308, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.2146, g_loss: 3.0839, D(x): 0.96, D(G(z)): 0.14
# Epoch [5/300], Step [400/600], d_loss: 0.2078, g_loss: 3.4677, D(x): 0.93, D(G(z)): 0.06
# Epoch [5/300], Step [600/600], d_loss: 0.0911, g_loss: 4.0711, D(x): 0.97, D(G(z)): 0.06
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.0957, g_loss: 4.5758, D(x): 0.98, D(G(z)): 0.07
# Epoch [6/300], Step [400/600], d_loss: 0.1368, g_loss: 4.2896, D(x): 0.97, D(G(z)): 0.09
# Epoch [6/300], Step [600/600], d_loss: 0.1784, g_loss: 6.7101, D(x): 0.97, D(G(z)): 0.11
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.2560, g_loss: 4.8824, D(x): 0.93, D(G(z)): 0.07
# Epoch [7/300], Step [400/600], d_loss: 0.1368, g_loss: 4.8422, D(x): 0.95, D(G(z)): 0.04
# Epoch [7/300], Step [600/600], d_loss: 0.0785, g_loss: 5.5121, D(x): 0.99, D(G(z)): 0.05
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1065, g_loss: 7.3123, D(x): 0.96, D(G(z)): 0.03
# Epoch [8/300], Step [400/600], d_loss: 0.0588, g_loss: 3.8157, D(x): 0.98, D(G(z)): 0.04
# Epoch [8/300], Step [600/600], d_loss: 0.2580, g_loss: 4.4436, D(x): 0.95, D(G(z)): 0.10
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.1078, g_loss: 6.7921, D(x): 0.96, D(G(z)): 0.01
# Epoch [9/300], Step [400/600], d_loss: 0.1414, g_loss: 6.9974, D(x): 0.97, D(G(z)): 0.05
# Epoch [9/300], Step [600/600], d_loss: 0.0525, g_loss: 6.7842, D(x): 0.98, D(G(z)): 0.01
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.0836, g_loss: 5.8503, D(x): 0.96, D(G(z)): 0.03
# Epoch [10/300], Step [400/600], d_loss: 0.2677, g_loss: 9.0840, D(x): 0.90, D(G(z)): 0.00
# Epoch [10/300], Step [600/600], d_loss: 0.0941, g_loss: 4.6288, D(x): 0.97, D(G(z)): 0.05
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.2219, g_loss: 5.3040, D(x): 0.95, D(G(z)): 0.04
# Epoch [11/300], Step [400/600], d_loss: 0.3027, g_loss: 7.1871, D(x): 0.89, D(G(z)): 0.01
# Epoch [11/300], Step [600/600], d_loss: 0.1865, g_loss: 5.1123, D(x): 0.92, D(G(z)): 0.02
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.2526, g_loss: 4.6634, D(x): 0.92, D(G(z)): 0.07
# Epoch [12/300], Step [400/600], d_loss: 0.1088, g_loss: 5.7153, D(x): 0.97, D(G(z)): 0.05
# Epoch [12/300], Step [600/600], d_loss: 0.3652, g_loss: 5.4449, D(x): 0.85, D(G(z)): 0.00
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.0801, g_loss: 5.9811, D(x): 0.96, D(G(z)): 0.01
# Epoch [13/300], Step [400/600], d_loss: 0.3005, g_loss: 3.8262, D(x): 0.94, D(G(z)): 0.12
# Epoch [13/300], Step [600/600], d_loss: 0.3366, g_loss: 3.3575, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.4254, g_loss: 3.4192, D(x): 0.92, D(G(z)): 0.14
# Epoch [14/300], Step [400/600], d_loss: 0.4377, g_loss: 3.1855, D(x): 0.95, D(G(z)): 0.23
# Epoch [14/300], Step [600/600], d_loss: 0.1960, g_loss: 4.0301, D(x): 0.96, D(G(z)): 0.10
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.1951, g_loss: 3.8751, D(x): 0.96, D(G(z)): 0.07
# Epoch [15/300], Step [400/600], d_loss: 0.2066, g_loss: 4.7790, D(x): 0.96, D(G(z)): 0.07
# Epoch [15/300], Step [600/600], d_loss: 0.2074, g_loss: 5.7326, D(x): 0.91, D(G(z)): 0.01
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.2202, g_loss: 4.7683, D(x): 0.93, D(G(z)): 0.05
# Epoch [16/300], Step [400/600], d_loss: 0.1325, g_loss: 6.5656, D(x): 0.95, D(G(z)): 0.04
# Epoch [16/300], Step [600/600], d_loss: 0.1599, g_loss: 6.4633, D(x): 0.94, D(G(z)): 0.03
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.5650, g_loss: 4.0102, D(x): 0.89, D(G(z)): 0.20
# Epoch [17/300], Step [400/600], d_loss: 0.3712, g_loss: 4.6348, D(x): 0.89, D(G(z)): 0.06
# Epoch [17/300], Step [600/600], d_loss: 0.2545, g_loss: 3.9732, D(x): 0.94, D(G(z)): 0.12
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.1322, g_loss: 5.4862, D(x): 0.96, D(G(z)): 0.04
# Epoch [18/300], Step [400/600], d_loss: 0.2649, g_loss: 5.4825, D(x): 0.99, D(G(z)): 0.15
# Epoch [18/300], Step [600/600], d_loss: 0.2059, g_loss: 4.4132, D(x): 0.94, D(G(z)): 0.06
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.2591, g_loss: 9.8473, D(x): 0.89, D(G(z)): 0.00
# Epoch [19/300], Step [400/600], d_loss: 0.1727, g_loss: 4.8952, D(x): 0.93, D(G(z)): 0.03
# Epoch [19/300], Step [600/600], d_loss: 0.2745, g_loss: 3.4123, D(x): 0.94, D(G(z)): 0.09
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2314, g_loss: 5.4850, D(x): 0.92, D(G(z)): 0.02
# Epoch [20/300], Step [400/600], d_loss: 0.1969, g_loss: 5.9657, D(x): 0.92, D(G(z)): 0.02
# Epoch [20/300], Step [600/600], d_loss: 0.4809, g_loss: 3.3559, D(x): 0.98, D(G(z)): 0.27
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.3235, g_loss: 5.1176, D(x): 0.90, D(G(z)): 0.03
# Epoch [21/300], Step [400/600], d_loss: 0.1850, g_loss: 4.6123, D(x): 0.96, D(G(z)): 0.10
# Epoch [21/300], Step [600/600], d_loss: 0.2268, g_loss: 3.1348, D(x): 0.92, D(G(z)): 0.06
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.2915, g_loss: 4.1392, D(x): 0.92, D(G(z)): 0.12
# Epoch [22/300], Step [400/600], d_loss: 0.2255, g_loss: 4.5282, D(x): 0.91, D(G(z)): 0.04
# Epoch [22/300], Step [600/600], d_loss: 0.2759, g_loss: 6.3814, D(x): 0.94, D(G(z)): 0.10
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.1138, g_loss: 4.8448, D(x): 0.98, D(G(z)): 0.06
# Epoch [23/300], Step [400/600], d_loss: 0.2391, g_loss: 3.9626, D(x): 0.94, D(G(z)): 0.07
# Epoch [23/300], Step [600/600], d_loss: 0.3746, g_loss: 4.8029, D(x): 0.97, D(G(z)): 0.21
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.2761, g_loss: 4.2189, D(x): 0.90, D(G(z)): 0.03
# Epoch [24/300], Step [400/600], d_loss: 0.1607, g_loss: 5.0153, D(x): 0.96, D(G(z)): 0.05
# Epoch [24/300], Step [600/600], d_loss: 0.3518, g_loss: 4.4060, D(x): 0.95, D(G(z)): 0.13
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2771, g_loss: 4.6253, D(x): 0.95, D(G(z)): 0.10
# Epoch [25/300], Step [400/600], d_loss: 0.2060, g_loss: 5.1007, D(x): 0.92, D(G(z)): 0.03
# Epoch [25/300], Step [600/600], d_loss: 0.2338, g_loss: 4.8856, D(x): 0.92, D(G(z)): 0.03
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.3029, g_loss: 5.2791, D(x): 0.91, D(G(z)): 0.08
# Epoch [26/300], Step [400/600], d_loss: 0.3249, g_loss: 5.7940, D(x): 0.87, D(G(z)): 0.03
# Epoch [26/300], Step [600/600], d_loss: 0.2806, g_loss: 2.7797, D(x): 0.96, D(G(z)): 0.16
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.2153, g_loss: 3.9490, D(x): 0.95, D(G(z)): 0.10
# Epoch [27/300], Step [400/600], d_loss: 0.3820, g_loss: 3.2380, D(x): 0.87, D(G(z)): 0.04
# Epoch [27/300], Step [600/600], d_loss: 0.4667, g_loss: 4.6585, D(x): 0.83, D(G(z)): 0.04
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.1438, g_loss: 3.6104, D(x): 0.96, D(G(z)): 0.08
# Epoch [28/300], Step [400/600], d_loss: 0.2833, g_loss: 4.4196, D(x): 0.94, D(G(z)): 0.14
# Epoch [28/300], Step [600/600], d_loss: 0.2584, g_loss: 2.9976, D(x): 0.91, D(G(z)): 0.10
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.2465, g_loss: 5.1494, D(x): 0.92, D(G(z)): 0.10
# Epoch [29/300], Step [400/600], d_loss: 0.3827, g_loss: 3.8038, D(x): 0.90, D(G(z)): 0.13
# Epoch [29/300], Step [600/600], d_loss: 0.3753, g_loss: 4.5884, D(x): 0.85, D(G(z)): 0.05
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.3703, g_loss: 4.2611, D(x): 0.89, D(G(z)): 0.10
# Epoch [30/300], Step [400/600], d_loss: 0.3996, g_loss: 4.6571, D(x): 0.85, D(G(z)): 0.07
# Epoch [30/300], Step [600/600], d_loss: 0.4049, g_loss: 3.9715, D(x): 0.91, D(G(z)): 0.11
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.5110, g_loss: 4.4908, D(x): 0.93, D(G(z)): 0.18
# Epoch [31/300], Step [400/600], d_loss: 0.2785, g_loss: 4.4685, D(x): 0.95, D(G(z)): 0.15
# Epoch [31/300], Step [600/600], d_loss: 0.6497, g_loss: 4.0112, D(x): 0.82, D(G(z)): 0.09
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.2684, g_loss: 3.9510, D(x): 0.95, D(G(z)): 0.11
# Epoch [32/300], Step [400/600], d_loss: 0.1955, g_loss: 4.5148, D(x): 0.93, D(G(z)): 0.05
# Epoch [32/300], Step [600/600], d_loss: 0.3150, g_loss: 5.5819, D(x): 0.93, D(G(z)): 0.10
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.2349, g_loss: 4.3445, D(x): 0.95, D(G(z)): 0.12
# Epoch [33/300], Step [400/600], d_loss: 0.2480, g_loss: 3.8674, D(x): 0.92, D(G(z)): 0.06
# Epoch [33/300], Step [600/600], d_loss: 0.2727, g_loss: 3.8256, D(x): 0.92, D(G(z)): 0.10
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.4151, g_loss: 3.5720, D(x): 0.84, D(G(z)): 0.06
# Epoch [34/300], Step [400/600], d_loss: 0.4453, g_loss: 4.6843, D(x): 0.90, D(G(z)): 0.15
# Epoch [34/300], Step [600/600], d_loss: 0.3601, g_loss: 3.4392, D(x): 0.90, D(G(z)): 0.12
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.6020, g_loss: 3.0219, D(x): 0.92, D(G(z)): 0.25
# Epoch [35/300], Step [400/600], d_loss: 0.4575, g_loss: 3.4336, D(x): 0.89, D(G(z)): 0.19
# Epoch [35/300], Step [600/600], d_loss: 0.4827, g_loss: 2.8620, D(x): 0.86, D(G(z)): 0.18
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.4402, g_loss: 3.1056, D(x): 0.86, D(G(z)): 0.14
# Epoch [36/300], Step [400/600], d_loss: 0.6228, g_loss: 3.8772, D(x): 0.80, D(G(z)): 0.14
# Epoch [36/300], Step [600/600], d_loss: 0.6416, g_loss: 2.5198, D(x): 0.79, D(G(z)): 0.11
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4200, g_loss: 2.9602, D(x): 0.90, D(G(z)): 0.18
# Epoch [37/300], Step [400/600], d_loss: 0.6922, g_loss: 2.9205, D(x): 0.82, D(G(z)): 0.17
# Epoch [37/300], Step [600/600], d_loss: 0.4144, g_loss: 2.9190, D(x): 0.89, D(G(z)): 0.16
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.4373, g_loss: 1.8523, D(x): 0.89, D(G(z)): 0.20
# Epoch [38/300], Step [400/600], d_loss: 0.3829, g_loss: 2.9621, D(x): 0.89, D(G(z)): 0.16
# Epoch [38/300], Step [600/600], d_loss: 0.4490, g_loss: 3.4807, D(x): 0.81, D(G(z)): 0.09
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.4010, g_loss: 4.0419, D(x): 0.86, D(G(z)): 0.10
# Epoch [39/300], Step [400/600], d_loss: 0.5626, g_loss: 2.9048, D(x): 0.80, D(G(z)): 0.09
# Epoch [39/300], Step [600/600], d_loss: 0.4953, g_loss: 4.2337, D(x): 0.83, D(G(z)): 0.10
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.3564, g_loss: 3.3524, D(x): 0.87, D(G(z)): 0.11
# Epoch [40/300], Step [400/600], d_loss: 0.5166, g_loss: 2.6402, D(x): 0.94, D(G(z)): 0.28
# Epoch [40/300], Step [600/600], d_loss: 0.6303, g_loss: 3.7127, D(x): 0.83, D(G(z)): 0.20
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.4018, g_loss: 4.2680, D(x): 0.86, D(G(z)): 0.10
# Epoch [41/300], Step [400/600], d_loss: 0.4424, g_loss: 3.3619, D(x): 0.86, D(G(z)): 0.11
# Epoch [41/300], Step [600/600], d_loss: 0.2710, g_loss: 4.8267, D(x): 0.90, D(G(z)): 0.04
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.3590, g_loss: 3.6284, D(x): 0.88, D(G(z)): 0.11
# Epoch [42/300], Step [400/600], d_loss: 0.4636, g_loss: 3.5195, D(x): 0.92, D(G(z)): 0.23
# Epoch [42/300], Step [600/600], d_loss: 0.4780, g_loss: 3.7083, D(x): 0.81, D(G(z)): 0.09
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.5827, g_loss: 3.2596, D(x): 0.85, D(G(z)): 0.18
# Epoch [43/300], Step [400/600], d_loss: 0.5492, g_loss: 3.5041, D(x): 0.86, D(G(z)): 0.19
# Epoch [43/300], Step [600/600], d_loss: 0.6854, g_loss: 2.5305, D(x): 0.88, D(G(z)): 0.28
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.5413, g_loss: 4.3521, D(x): 0.82, D(G(z)): 0.05
# Epoch [44/300], Step [400/600], d_loss: 0.4771, g_loss: 3.4701, D(x): 0.82, D(G(z)): 0.10
# Epoch [44/300], Step [600/600], d_loss: 0.7668, g_loss: 1.9550, D(x): 0.80, D(G(z)): 0.24
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.5804, g_loss: 2.3833, D(x): 0.84, D(G(z)): 0.19
# Epoch [45/300], Step [400/600], d_loss: 0.5817, g_loss: 1.9676, D(x): 0.82, D(G(z)): 0.15
# Epoch [45/300], Step [600/600], d_loss: 0.3905, g_loss: 2.6857, D(x): 0.87, D(G(z)): 0.13
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.6314, g_loss: 1.9603, D(x): 0.77, D(G(z)): 0.15
# Epoch [46/300], Step [400/600], d_loss: 0.5541, g_loss: 2.1762, D(x): 0.87, D(G(z)): 0.22
# Epoch [46/300], Step [600/600], d_loss: 0.8664, g_loss: 3.1953, D(x): 0.81, D(G(z)): 0.30
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.4440, g_loss: 3.0868, D(x): 0.87, D(G(z)): 0.18
# Epoch [47/300], Step [400/600], d_loss: 0.5910, g_loss: 2.2190, D(x): 0.81, D(G(z)): 0.19
# Epoch [47/300], Step [600/600], d_loss: 0.6311, g_loss: 2.1701, D(x): 0.82, D(G(z)): 0.22
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.5537, g_loss: 2.8422, D(x): 0.86, D(G(z)): 0.24
# Epoch [48/300], Step [400/600], d_loss: 0.3887, g_loss: 3.0840, D(x): 0.88, D(G(z)): 0.15
# Epoch [48/300], Step [600/600], d_loss: 0.5646, g_loss: 2.6480, D(x): 0.79, D(G(z)): 0.15
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.6288, g_loss: 2.2301, D(x): 0.76, D(G(z)): 0.15
# Epoch [49/300], Step [400/600], d_loss: 0.4172, g_loss: 2.2830, D(x): 0.81, D(G(z)): 0.12
# Epoch [49/300], Step [600/600], d_loss: 0.6707, g_loss: 3.2216, D(x): 0.77, D(G(z)): 0.14
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.6313, g_loss: 2.1393, D(x): 0.82, D(G(z)): 0.21
# Epoch [50/300], Step [400/600], d_loss: 0.5426, g_loss: 2.2112, D(x): 0.87, D(G(z)): 0.22
# Epoch [50/300], Step [600/600], d_loss: 0.4258, g_loss: 2.5839, D(x): 0.83, D(G(z)): 0.14
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.3635, g_loss: 2.9510, D(x): 0.92, D(G(z)): 0.15
# Epoch [51/300], Step [400/600], d_loss: 0.5206, g_loss: 2.3415, D(x): 0.88, D(G(z)): 0.23
# Epoch [51/300], Step [600/600], d_loss: 0.4740, g_loss: 2.4763, D(x): 0.91, D(G(z)): 0.24
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.5719, g_loss: 2.6825, D(x): 0.85, D(G(z)): 0.23
# Epoch [52/300], Step [400/600], d_loss: 0.6122, g_loss: 3.2147, D(x): 0.75, D(G(z)): 0.11
# Epoch [52/300], Step [600/600], d_loss: 0.7390, g_loss: 2.7845, D(x): 0.78, D(G(z)): 0.15
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.4173, g_loss: 3.6942, D(x): 0.84, D(G(z)): 0.11
# Epoch [53/300], Step [400/600], d_loss: 0.5207, g_loss: 2.6598, D(x): 0.84, D(G(z)): 0.18
# Epoch [53/300], Step [600/600], d_loss: 0.3977, g_loss: 3.0523, D(x): 0.82, D(G(z)): 0.07
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.6010, g_loss: 1.7929, D(x): 0.85, D(G(z)): 0.24
# Epoch [54/300], Step [400/600], d_loss: 0.5183, g_loss: 2.8776, D(x): 0.87, D(G(z)): 0.22
# Epoch [54/300], Step [600/600], d_loss: 0.7042, g_loss: 2.1122, D(x): 0.74, D(G(z)): 0.13
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.6666, g_loss: 3.0513, D(x): 0.80, D(G(z)): 0.18
# Epoch [55/300], Step [400/600], d_loss: 0.5758, g_loss: 3.0085, D(x): 0.80, D(G(z)): 0.14
# Epoch [55/300], Step [600/600], d_loss: 0.5815, g_loss: 2.2497, D(x): 0.86, D(G(z)): 0.25
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.8151, g_loss: 2.0927, D(x): 0.88, D(G(z)): 0.33
# Epoch [56/300], Step [400/600], d_loss: 0.7298, g_loss: 3.0862, D(x): 0.78, D(G(z)): 0.21
# Epoch [56/300], Step [600/600], d_loss: 0.4704, g_loss: 2.4524, D(x): 0.87, D(G(z)): 0.21
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.7025, g_loss: 2.2229, D(x): 0.76, D(G(z)): 0.17
# Epoch [57/300], Step [400/600], d_loss: 0.7452, g_loss: 2.0543, D(x): 0.73, D(G(z)): 0.12
# Epoch [57/300], Step [600/600], d_loss: 0.5870, g_loss: 2.5104, D(x): 0.86, D(G(z)): 0.23
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.8209, g_loss: 2.0992, D(x): 0.69, D(G(z)): 0.16
# Epoch [58/300], Step [400/600], d_loss: 0.5925, g_loss: 2.4919, D(x): 0.76, D(G(z)): 0.16
# Epoch [58/300], Step [600/600], d_loss: 0.7881, g_loss: 2.0826, D(x): 0.86, D(G(z)): 0.34
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.6041, g_loss: 3.0542, D(x): 0.78, D(G(z)): 0.15
# Epoch [59/300], Step [400/600], d_loss: 0.7052, g_loss: 2.0218, D(x): 0.76, D(G(z)): 0.24
# Epoch [59/300], Step [600/600], d_loss: 0.6055, g_loss: 2.4233, D(x): 0.85, D(G(z)): 0.24
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.5800, g_loss: 2.8383, D(x): 0.81, D(G(z)): 0.19
# Epoch [60/300], Step [400/600], d_loss: 0.6694, g_loss: 2.2228, D(x): 0.73, D(G(z)): 0.14
# Epoch [60/300], Step [600/600], d_loss: 0.7775, g_loss: 1.7976, D(x): 0.70, D(G(z)): 0.18
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.7119, g_loss: 2.0144, D(x): 0.73, D(G(z)): 0.13
# Epoch [61/300], Step [400/600], d_loss: 0.5107, g_loss: 2.2775, D(x): 0.80, D(G(z)): 0.13
# Epoch [61/300], Step [600/600], d_loss: 0.6473, g_loss: 2.6582, D(x): 0.83, D(G(z)): 0.28
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.6408, g_loss: 2.2367, D(x): 0.79, D(G(z)): 0.20
# Epoch [62/300], Step [400/600], d_loss: 0.4881, g_loss: 2.9113, D(x): 0.86, D(G(z)): 0.21
# Epoch [62/300], Step [600/600], d_loss: 0.5501, g_loss: 1.5913, D(x): 0.79, D(G(z)): 0.16
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.3758, g_loss: 2.7800, D(x): 0.89, D(G(z)): 0.17
# Epoch [63/300], Step [400/600], d_loss: 0.5367, g_loss: 3.1263, D(x): 0.80, D(G(z)): 0.13
# Epoch [63/300], Step [600/600], d_loss: 0.7675, g_loss: 1.8200, D(x): 0.84, D(G(z)): 0.33
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.6314, g_loss: 2.5572, D(x): 0.86, D(G(z)): 0.27
# Epoch [64/300], Step [400/600], d_loss: 0.6660, g_loss: 2.1453, D(x): 0.83, D(G(z)): 0.28
# Epoch [64/300], Step [600/600], d_loss: 0.8440, g_loss: 2.0921, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.5486, g_loss: 2.3763, D(x): 0.85, D(G(z)): 0.21
# Epoch [65/300], Step [400/600], d_loss: 0.5113, g_loss: 3.1782, D(x): 0.78, D(G(z)): 0.11
# Epoch [65/300], Step [600/600], d_loss: 0.5498, g_loss: 3.2547, D(x): 0.79, D(G(z)): 0.13
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.5740, g_loss: 2.0656, D(x): 0.80, D(G(z)): 0.18
# Epoch [66/300], Step [400/600], d_loss: 0.3891, g_loss: 3.2199, D(x): 0.87, D(G(z)): 0.16
# Epoch [66/300], Step [600/600], d_loss: 0.6174, g_loss: 2.2542, D(x): 0.85, D(G(z)): 0.24
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.5274, g_loss: 2.8709, D(x): 0.80, D(G(z)): 0.14
# Epoch [67/300], Step [400/600], d_loss: 0.4889, g_loss: 2.6008, D(x): 0.84, D(G(z)): 0.18
# Epoch [67/300], Step [600/600], d_loss: 0.7474, g_loss: 2.6307, D(x): 0.78, D(G(z)): 0.23
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.5556, g_loss: 2.4382, D(x): 0.81, D(G(z)): 0.17
# Epoch [68/300], Step [400/600], d_loss: 0.7146, g_loss: 2.3450, D(x): 0.80, D(G(z)): 0.26
# Epoch [68/300], Step [600/600], d_loss: 0.6112, g_loss: 1.8798, D(x): 0.78, D(G(z)): 0.17
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.5383, g_loss: 2.1823, D(x): 0.76, D(G(z)): 0.14
# Epoch [69/300], Step [400/600], d_loss: 0.8903, g_loss: 1.9373, D(x): 0.71, D(G(z)): 0.19
# Epoch [69/300], Step [600/600], d_loss: 0.7214, g_loss: 1.8443, D(x): 0.82, D(G(z)): 0.26
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.6914, g_loss: 1.8495, D(x): 0.74, D(G(z)): 0.18
# Epoch [70/300], Step [400/600], d_loss: 0.6485, g_loss: 1.9924, D(x): 0.78, D(G(z)): 0.21
# Epoch [70/300], Step [600/600], d_loss: 0.6830, g_loss: 2.2055, D(x): 0.83, D(G(z)): 0.27
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.8559, g_loss: 1.9600, D(x): 0.78, D(G(z)): 0.32
# Epoch [71/300], Step [400/600], d_loss: 0.6525, g_loss: 1.9471, D(x): 0.82, D(G(z)): 0.26
# Epoch [71/300], Step [600/600], d_loss: 0.6217, g_loss: 2.4859, D(x): 0.80, D(G(z)): 0.20
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.6209, g_loss: 2.5075, D(x): 0.76, D(G(z)): 0.19
# Epoch [72/300], Step [400/600], d_loss: 0.7019, g_loss: 2.9926, D(x): 0.82, D(G(z)): 0.27
# Epoch [72/300], Step [600/600], d_loss: 0.8141, g_loss: 1.6785, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.6930, g_loss: 2.9378, D(x): 0.74, D(G(z)): 0.15
# Epoch [73/300], Step [400/600], d_loss: 0.6817, g_loss: 1.9824, D(x): 0.75, D(G(z)): 0.19
# Epoch [73/300], Step [600/600], d_loss: 0.4266, g_loss: 2.5857, D(x): 0.83, D(G(z)): 0.13
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.5617, g_loss: 2.0230, D(x): 0.85, D(G(z)): 0.24
# Epoch [74/300], Step [400/600], d_loss: 0.6926, g_loss: 2.2668, D(x): 0.80, D(G(z)): 0.27
# Epoch [74/300], Step [600/600], d_loss: 0.5575, g_loss: 2.3784, D(x): 0.86, D(G(z)): 0.25
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.7008, g_loss: 2.3388, D(x): 0.71, D(G(z)): 0.16
# Epoch [75/300], Step [400/600], d_loss: 0.6646, g_loss: 1.7662, D(x): 0.79, D(G(z)): 0.24
# Epoch [75/300], Step [600/600], d_loss: 0.6720, g_loss: 2.0745, D(x): 0.78, D(G(z)): 0.22
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.6013, g_loss: 2.3823, D(x): 0.81, D(G(z)): 0.20
# Epoch [76/300], Step [400/600], d_loss: 0.6237, g_loss: 2.2529, D(x): 0.74, D(G(z)): 0.15
# Epoch [76/300], Step [600/600], d_loss: 0.8174, g_loss: 1.3782, D(x): 0.79, D(G(z)): 0.33
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.7459, g_loss: 1.5883, D(x): 0.79, D(G(z)): 0.28
# Epoch [77/300], Step [400/600], d_loss: 0.7661, g_loss: 2.3469, D(x): 0.79, D(G(z)): 0.25
# Epoch [77/300], Step [600/600], d_loss: 0.7114, g_loss: 1.9553, D(x): 0.74, D(G(z)): 0.20
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.5890, g_loss: 2.3899, D(x): 0.81, D(G(z)): 0.19
# Epoch [78/300], Step [400/600], d_loss: 0.6718, g_loss: 1.9082, D(x): 0.72, D(G(z)): 0.15
# Epoch [78/300], Step [600/600], d_loss: 0.7189, g_loss: 2.1050, D(x): 0.76, D(G(z)): 0.22
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.5029, g_loss: 2.9080, D(x): 0.87, D(G(z)): 0.23
# Epoch [79/300], Step [400/600], d_loss: 0.7957, g_loss: 2.4528, D(x): 0.71, D(G(z)): 0.17
# Epoch [79/300], Step [600/600], d_loss: 0.6932, g_loss: 1.8111, D(x): 0.76, D(G(z)): 0.19
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.6112, g_loss: 2.5527, D(x): 0.77, D(G(z)): 0.16
# Epoch [80/300], Step [400/600], d_loss: 0.7287, g_loss: 2.2627, D(x): 0.74, D(G(z)): 0.20
# Epoch [80/300], Step [600/600], d_loss: 0.6776, g_loss: 1.9856, D(x): 0.77, D(G(z)): 0.19
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.7457, g_loss: 1.8468, D(x): 0.78, D(G(z)): 0.26
# Epoch [81/300], Step [400/600], d_loss: 0.8194, g_loss: 2.1307, D(x): 0.72, D(G(z)): 0.21
# Epoch [81/300], Step [600/600], d_loss: 0.6236, g_loss: 1.9691, D(x): 0.80, D(G(z)): 0.20
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.9118, g_loss: 1.4447, D(x): 0.85, D(G(z)): 0.40
# Epoch [82/300], Step [400/600], d_loss: 0.6273, g_loss: 1.7861, D(x): 0.82, D(G(z)): 0.24
# Epoch [82/300], Step [600/600], d_loss: 0.9027, g_loss: 2.3611, D(x): 0.67, D(G(z)): 0.17
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.7695, g_loss: 1.5795, D(x): 0.77, D(G(z)): 0.25
# Epoch [83/300], Step [400/600], d_loss: 0.6459, g_loss: 2.3184, D(x): 0.79, D(G(z)): 0.23
# Epoch [83/300], Step [600/600], d_loss: 0.8540, g_loss: 1.5608, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.7554, g_loss: 2.5986, D(x): 0.78, D(G(z)): 0.26
# Epoch [84/300], Step [400/600], d_loss: 0.8464, g_loss: 2.3322, D(x): 0.72, D(G(z)): 0.23
# Epoch [84/300], Step [600/600], d_loss: 0.6881, g_loss: 1.9576, D(x): 0.79, D(G(z)): 0.25
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.7118, g_loss: 1.9983, D(x): 0.80, D(G(z)): 0.27
# Epoch [85/300], Step [400/600], d_loss: 0.6458, g_loss: 1.7324, D(x): 0.76, D(G(z)): 0.17
# Epoch [85/300], Step [600/600], d_loss: 0.5968, g_loss: 2.4882, D(x): 0.77, D(G(z)): 0.16
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.8009, g_loss: 1.9553, D(x): 0.80, D(G(z)): 0.31
# Epoch [86/300], Step [400/600], d_loss: 0.5417, g_loss: 2.2132, D(x): 0.84, D(G(z)): 0.24
# Epoch [86/300], Step [600/600], d_loss: 0.6890, g_loss: 2.1508, D(x): 0.77, D(G(z)): 0.23
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.6406, g_loss: 2.0693, D(x): 0.80, D(G(z)): 0.23
# Epoch [87/300], Step [400/600], d_loss: 0.7342, g_loss: 2.6115, D(x): 0.76, D(G(z)): 0.22
# Epoch [87/300], Step [600/600], d_loss: 0.5602, g_loss: 2.2033, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.6277, g_loss: 2.3312, D(x): 0.77, D(G(z)): 0.18
# Epoch [88/300], Step [400/600], d_loss: 0.7405, g_loss: 1.8245, D(x): 0.82, D(G(z)): 0.32
# Epoch [88/300], Step [600/600], d_loss: 0.8401, g_loss: 1.9292, D(x): 0.83, D(G(z)): 0.35
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.6579, g_loss: 2.2787, D(x): 0.81, D(G(z)): 0.26
# Epoch [89/300], Step [400/600], d_loss: 0.8272, g_loss: 2.3578, D(x): 0.69, D(G(z)): 0.17
# Epoch [89/300], Step [600/600], d_loss: 0.8555, g_loss: 2.1561, D(x): 0.77, D(G(z)): 0.31
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.7262, g_loss: 2.6435, D(x): 0.78, D(G(z)): 0.24
# Epoch [90/300], Step [400/600], d_loss: 0.7322, g_loss: 1.8672, D(x): 0.79, D(G(z)): 0.26
# Epoch [90/300], Step [600/600], d_loss: 0.9431, g_loss: 1.8461, D(x): 0.78, D(G(z)): 0.34
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.7790, g_loss: 2.1909, D(x): 0.75, D(G(z)): 0.23
# Epoch [91/300], Step [400/600], d_loss: 0.7794, g_loss: 2.0000, D(x): 0.76, D(G(z)): 0.30
# Epoch [91/300], Step [600/600], d_loss: 0.8508, g_loss: 1.9362, D(x): 0.81, D(G(z)): 0.33
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.7243, g_loss: 1.6651, D(x): 0.81, D(G(z)): 0.29
# Epoch [92/300], Step [400/600], d_loss: 1.0715, g_loss: 1.5397, D(x): 0.78, D(G(z)): 0.42
# Epoch [92/300], Step [600/600], d_loss: 0.8199, g_loss: 2.0539, D(x): 0.70, D(G(z)): 0.17
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 1.0118, g_loss: 1.7149, D(x): 0.65, D(G(z)): 0.23
# Epoch [93/300], Step [400/600], d_loss: 0.6997, g_loss: 1.9074, D(x): 0.82, D(G(z)): 0.30
# Epoch [93/300], Step [600/600], d_loss: 0.6150, g_loss: 1.5945, D(x): 0.81, D(G(z)): 0.24
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.8403, g_loss: 2.2899, D(x): 0.66, D(G(z)): 0.20
# Epoch [94/300], Step [400/600], d_loss: 0.8634, g_loss: 1.7436, D(x): 0.74, D(G(z)): 0.28
# Epoch [94/300], Step [600/600], d_loss: 0.7718, g_loss: 2.0109, D(x): 0.73, D(G(z)): 0.22
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.7488, g_loss: 1.8237, D(x): 0.74, D(G(z)): 0.25
# Epoch [95/300], Step [400/600], d_loss: 1.0215, g_loss: 1.3174, D(x): 0.65, D(G(z)): 0.24
# Epoch [95/300], Step [600/600], d_loss: 0.5991, g_loss: 1.9065, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 1.0135, g_loss: 2.2145, D(x): 0.72, D(G(z)): 0.29
# Epoch [96/300], Step [400/600], d_loss: 0.7919, g_loss: 2.0581, D(x): 0.72, D(G(z)): 0.22
# Epoch [96/300], Step [600/600], d_loss: 0.7516, g_loss: 2.1665, D(x): 0.73, D(G(z)): 0.23
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.8720, g_loss: 1.8424, D(x): 0.65, D(G(z)): 0.16
# Epoch [97/300], Step [400/600], d_loss: 0.9166, g_loss: 1.4008, D(x): 0.67, D(G(z)): 0.24
# Epoch [97/300], Step [600/600], d_loss: 0.9121, g_loss: 1.9734, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.7636, g_loss: 1.6929, D(x): 0.74, D(G(z)): 0.24
# Epoch [98/300], Step [400/600], d_loss: 0.8003, g_loss: 1.4318, D(x): 0.77, D(G(z)): 0.30
# Epoch [98/300], Step [600/600], d_loss: 0.8620, g_loss: 1.5679, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.8947, g_loss: 1.5710, D(x): 0.66, D(G(z)): 0.22
# Epoch [99/300], Step [400/600], d_loss: 0.9039, g_loss: 1.7543, D(x): 0.69, D(G(z)): 0.26
# Epoch [99/300], Step [600/600], d_loss: 0.8895, g_loss: 1.4161, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.9312, g_loss: 1.6989, D(x): 0.76, D(G(z)): 0.32
# Epoch [100/300], Step [400/600], d_loss: 0.8336, g_loss: 1.8625, D(x): 0.76, D(G(z)): 0.28
# Epoch [100/300], Step [600/600], d_loss: 0.7929, g_loss: 2.5935, D(x): 0.77, D(G(z)): 0.25
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.7856, g_loss: 1.8610, D(x): 0.79, D(G(z)): 0.30
# Epoch [101/300], Step [400/600], d_loss: 0.6818, g_loss: 2.2086, D(x): 0.77, D(G(z)): 0.23
# Epoch [101/300], Step [600/600], d_loss: 0.7112, g_loss: 1.8972, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.7919, g_loss: 1.8036, D(x): 0.76, D(G(z)): 0.30
# Epoch [102/300], Step [400/600], d_loss: 0.8329, g_loss: 1.9290, D(x): 0.67, D(G(z)): 0.16
# Epoch [102/300], Step [600/600], d_loss: 0.6526, g_loss: 1.5990, D(x): 0.79, D(G(z)): 0.25
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.7655, g_loss: 2.8034, D(x): 0.66, D(G(z)): 0.14
# Epoch [103/300], Step [400/600], d_loss: 0.7545, g_loss: 2.7270, D(x): 0.76, D(G(z)): 0.27
# Epoch [103/300], Step [600/600], d_loss: 0.7694, g_loss: 1.7097, D(x): 0.79, D(G(z)): 0.29
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.8033, g_loss: 1.8979, D(x): 0.71, D(G(z)): 0.23
# Epoch [104/300], Step [400/600], d_loss: 0.7106, g_loss: 1.8268, D(x): 0.75, D(G(z)): 0.24
# Epoch [104/300], Step [600/600], d_loss: 0.7856, g_loss: 2.0809, D(x): 0.68, D(G(z)): 0.20
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.7129, g_loss: 2.0193, D(x): 0.72, D(G(z)): 0.20
# Epoch [105/300], Step [400/600], d_loss: 0.7274, g_loss: 1.6272, D(x): 0.76, D(G(z)): 0.26
# Epoch [105/300], Step [600/600], d_loss: 0.6316, g_loss: 2.3095, D(x): 0.83, D(G(z)): 0.26
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.7559, g_loss: 1.5567, D(x): 0.76, D(G(z)): 0.24
# Epoch [106/300], Step [400/600], d_loss: 0.8292, g_loss: 1.6903, D(x): 0.68, D(G(z)): 0.22
# Epoch [106/300], Step [600/600], d_loss: 0.7750, g_loss: 1.9426, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.9532, g_loss: 2.3042, D(x): 0.71, D(G(z)): 0.33
# Epoch [107/300], Step [400/600], d_loss: 0.7370, g_loss: 2.1112, D(x): 0.70, D(G(z)): 0.21
# Epoch [107/300], Step [600/600], d_loss: 0.6721, g_loss: 2.1606, D(x): 0.71, D(G(z)): 0.17
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.7239, g_loss: 1.9278, D(x): 0.79, D(G(z)): 0.26
# Epoch [108/300], Step [400/600], d_loss: 0.7113, g_loss: 1.9475, D(x): 0.78, D(G(z)): 0.27
# Epoch [108/300], Step [600/600], d_loss: 0.8407, g_loss: 1.8435, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.8208, g_loss: 1.8800, D(x): 0.74, D(G(z)): 0.28
# Epoch [109/300], Step [400/600], d_loss: 0.9953, g_loss: 1.6188, D(x): 0.72, D(G(z)): 0.33
# Epoch [109/300], Step [600/600], d_loss: 0.8129, g_loss: 1.9610, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.5818, g_loss: 2.5618, D(x): 0.77, D(G(z)): 0.17
# Epoch [110/300], Step [400/600], d_loss: 0.6581, g_loss: 2.3415, D(x): 0.78, D(G(z)): 0.25
# Epoch [110/300], Step [600/600], d_loss: 0.9536, g_loss: 1.5396, D(x): 0.81, D(G(z)): 0.39
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.8936, g_loss: 1.4057, D(x): 0.70, D(G(z)): 0.29
# Epoch [111/300], Step [400/600], d_loss: 0.8879, g_loss: 1.4817, D(x): 0.61, D(G(z)): 0.17
# Epoch [111/300], Step [600/600], d_loss: 1.0756, g_loss: 1.6466, D(x): 0.75, D(G(z)): 0.37
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.8644, g_loss: 1.4685, D(x): 0.72, D(G(z)): 0.30
# Epoch [112/300], Step [400/600], d_loss: 0.6891, g_loss: 1.9106, D(x): 0.79, D(G(z)): 0.25
# Epoch [112/300], Step [600/600], d_loss: 0.8715, g_loss: 1.6691, D(x): 0.81, D(G(z)): 0.34
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.8055, g_loss: 1.7959, D(x): 0.72, D(G(z)): 0.21
# Epoch [113/300], Step [400/600], d_loss: 0.8029, g_loss: 2.0545, D(x): 0.68, D(G(z)): 0.19
# Epoch [113/300], Step [600/600], d_loss: 1.0122, g_loss: 1.9559, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.9833, g_loss: 1.7182, D(x): 0.68, D(G(z)): 0.27
# Epoch [114/300], Step [400/600], d_loss: 0.9368, g_loss: 2.0479, D(x): 0.75, D(G(z)): 0.31
# Epoch [114/300], Step [600/600], d_loss: 1.0451, g_loss: 1.8254, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.8066, g_loss: 1.7569, D(x): 0.77, D(G(z)): 0.30
# Epoch [115/300], Step [400/600], d_loss: 0.8720, g_loss: 1.6747, D(x): 0.69, D(G(z)): 0.25
# Epoch [115/300], Step [600/600], d_loss: 0.7709, g_loss: 1.8440, D(x): 0.76, D(G(z)): 0.28
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.8737, g_loss: 1.6665, D(x): 0.76, D(G(z)): 0.32
# Epoch [116/300], Step [400/600], d_loss: 0.8347, g_loss: 1.6826, D(x): 0.67, D(G(z)): 0.19
# Epoch [116/300], Step [600/600], d_loss: 0.8823, g_loss: 1.7789, D(x): 0.78, D(G(z)): 0.35
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.7979, g_loss: 2.1963, D(x): 0.67, D(G(z)): 0.19
# Epoch [117/300], Step [400/600], d_loss: 0.9780, g_loss: 1.5714, D(x): 0.71, D(G(z)): 0.30
# Epoch [117/300], Step [600/600], d_loss: 0.8491, g_loss: 1.9542, D(x): 0.70, D(G(z)): 0.25
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.7546, g_loss: 1.8744, D(x): 0.75, D(G(z)): 0.26
# Epoch [118/300], Step [400/600], d_loss: 0.7873, g_loss: 1.8893, D(x): 0.81, D(G(z)): 0.35
# Epoch [118/300], Step [600/600], d_loss: 0.6947, g_loss: 1.8934, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.8208, g_loss: 1.9466, D(x): 0.67, D(G(z)): 0.17
# Epoch [119/300], Step [400/600], d_loss: 0.9448, g_loss: 2.0448, D(x): 0.78, D(G(z)): 0.35
# Epoch [119/300], Step [600/600], d_loss: 1.0452, g_loss: 1.8720, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.9291, g_loss: 1.5246, D(x): 0.77, D(G(z)): 0.37
# Epoch [120/300], Step [400/600], d_loss: 0.9334, g_loss: 1.6065, D(x): 0.69, D(G(z)): 0.29
# Epoch [120/300], Step [600/600], d_loss: 0.8810, g_loss: 1.7685, D(x): 0.77, D(G(z)): 0.36
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.7498, g_loss: 1.9233, D(x): 0.74, D(G(z)): 0.24
# Epoch [121/300], Step [400/600], d_loss: 0.9170, g_loss: 1.2159, D(x): 0.79, D(G(z)): 0.40
# Epoch [121/300], Step [600/600], d_loss: 0.8892, g_loss: 1.9211, D(x): 0.67, D(G(z)): 0.26
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 1.1070, g_loss: 1.4634, D(x): 0.77, D(G(z)): 0.47
# Epoch [122/300], Step [400/600], d_loss: 0.9745, g_loss: 1.3321, D(x): 0.70, D(G(z)): 0.36
# Epoch [122/300], Step [600/600], d_loss: 0.9063, g_loss: 1.1170, D(x): 0.81, D(G(z)): 0.40
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.9683, g_loss: 1.8486, D(x): 0.67, D(G(z)): 0.27
# Epoch [123/300], Step [400/600], d_loss: 0.8898, g_loss: 1.8079, D(x): 0.68, D(G(z)): 0.26
# Epoch [123/300], Step [600/600], d_loss: 1.0191, g_loss: 1.8386, D(x): 0.66, D(G(z)): 0.31
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.8129, g_loss: 1.5117, D(x): 0.76, D(G(z)): 0.32
# Epoch [124/300], Step [400/600], d_loss: 0.6491, g_loss: 2.0144, D(x): 0.78, D(G(z)): 0.22
# Epoch [124/300], Step [600/600], d_loss: 0.8020, g_loss: 1.4693, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.9180, g_loss: 1.6844, D(x): 0.69, D(G(z)): 0.28
# Epoch [125/300], Step [400/600], d_loss: 0.7678, g_loss: 1.5911, D(x): 0.70, D(G(z)): 0.20
# Epoch [125/300], Step [600/600], d_loss: 0.9056, g_loss: 1.6998, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.8706, g_loss: 1.7418, D(x): 0.67, D(G(z)): 0.21
# Epoch [126/300], Step [400/600], d_loss: 1.0592, g_loss: 1.4014, D(x): 0.63, D(G(z)): 0.26
# Epoch [126/300], Step [600/600], d_loss: 0.9423, g_loss: 1.1985, D(x): 0.76, D(G(z)): 0.37
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.9383, g_loss: 1.4448, D(x): 0.68, D(G(z)): 0.31
# Epoch [127/300], Step [400/600], d_loss: 0.9529, g_loss: 2.3719, D(x): 0.64, D(G(z)): 0.19
# Epoch [127/300], Step [600/600], d_loss: 0.9609, g_loss: 1.6960, D(x): 0.62, D(G(z)): 0.23
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.8600, g_loss: 1.3085, D(x): 0.71, D(G(z)): 0.26
# Epoch [128/300], Step [400/600], d_loss: 1.0868, g_loss: 1.5702, D(x): 0.76, D(G(z)): 0.42
# Epoch [128/300], Step [600/600], d_loss: 0.8324, g_loss: 1.7641, D(x): 0.76, D(G(z)): 0.32
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.9236, g_loss: 1.5764, D(x): 0.68, D(G(z)): 0.27
# Epoch [129/300], Step [400/600], d_loss: 0.7584, g_loss: 2.0668, D(x): 0.74, D(G(z)): 0.26
# Epoch [129/300], Step [600/600], d_loss: 0.9409, g_loss: 1.4166, D(x): 0.77, D(G(z)): 0.38
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.9307, g_loss: 1.6816, D(x): 0.75, D(G(z)): 0.35
# Epoch [130/300], Step [400/600], d_loss: 1.1714, g_loss: 1.2645, D(x): 0.68, D(G(z)): 0.36
# Epoch [130/300], Step [600/600], d_loss: 0.7771, g_loss: 1.8237, D(x): 0.72, D(G(z)): 0.24
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.9336, g_loss: 1.8347, D(x): 0.73, D(G(z)): 0.34
# Epoch [131/300], Step [400/600], d_loss: 1.0488, g_loss: 1.4366, D(x): 0.62, D(G(z)): 0.26
# Epoch [131/300], Step [600/600], d_loss: 1.2037, g_loss: 1.4360, D(x): 0.62, D(G(z)): 0.25
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.9551, g_loss: 1.7461, D(x): 0.67, D(G(z)): 0.29
# Epoch [132/300], Step [400/600], d_loss: 0.8381, g_loss: 2.4019, D(x): 0.68, D(G(z)): 0.21
# Epoch [132/300], Step [600/600], d_loss: 0.8384, g_loss: 1.6464, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.6609, g_loss: 1.7635, D(x): 0.80, D(G(z)): 0.26
# Epoch [133/300], Step [400/600], d_loss: 1.0222, g_loss: 1.7588, D(x): 0.61, D(G(z)): 0.22
# Epoch [133/300], Step [600/600], d_loss: 0.7972, g_loss: 1.9577, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.8172, g_loss: 1.5367, D(x): 0.74, D(G(z)): 0.30
# Epoch [134/300], Step [400/600], d_loss: 0.8756, g_loss: 1.6527, D(x): 0.68, D(G(z)): 0.22
# Epoch [134/300], Step [600/600], d_loss: 0.8835, g_loss: 1.7393, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.9930, g_loss: 1.4202, D(x): 0.70, D(G(z)): 0.33
# Epoch [135/300], Step [400/600], d_loss: 0.9150, g_loss: 1.7791, D(x): 0.72, D(G(z)): 0.29
# Epoch [135/300], Step [600/600], d_loss: 0.7415, g_loss: 1.8455, D(x): 0.77, D(G(z)): 0.29
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.9938, g_loss: 1.4060, D(x): 0.84, D(G(z)): 0.45
# Epoch [136/300], Step [400/600], d_loss: 0.8336, g_loss: 1.7585, D(x): 0.74, D(G(z)): 0.30
# Epoch [136/300], Step [600/600], d_loss: 0.8746, g_loss: 1.6020, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.9407, g_loss: 1.4578, D(x): 0.81, D(G(z)): 0.40
# Epoch [137/300], Step [400/600], d_loss: 0.9564, g_loss: 1.6742, D(x): 0.69, D(G(z)): 0.30
# Epoch [137/300], Step [600/600], d_loss: 0.6279, g_loss: 2.4268, D(x): 0.77, D(G(z)): 0.22
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 1.0484, g_loss: 1.4494, D(x): 0.69, D(G(z)): 0.35
# Epoch [138/300], Step [400/600], d_loss: 0.9276, g_loss: 1.8700, D(x): 0.78, D(G(z)): 0.38
# Epoch [138/300], Step [600/600], d_loss: 0.8778, g_loss: 1.8814, D(x): 0.66, D(G(z)): 0.24
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.9064, g_loss: 1.6034, D(x): 0.70, D(G(z)): 0.30
# Epoch [139/300], Step [400/600], d_loss: 0.9188, g_loss: 1.5214, D(x): 0.70, D(G(z)): 0.29
# Epoch [139/300], Step [600/600], d_loss: 0.9768, g_loss: 1.7584, D(x): 0.64, D(G(z)): 0.25
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.9016, g_loss: 1.6936, D(x): 0.70, D(G(z)): 0.27
# Epoch [140/300], Step [400/600], d_loss: 0.6871, g_loss: 1.6630, D(x): 0.81, D(G(z)): 0.28
# Epoch [140/300], Step [600/600], d_loss: 0.9989, g_loss: 1.2882, D(x): 0.78, D(G(z)): 0.42
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.9205, g_loss: 1.3841, D(x): 0.76, D(G(z)): 0.37
# Epoch [141/300], Step [400/600], d_loss: 0.7742, g_loss: 1.2780, D(x): 0.74, D(G(z)): 0.28
# Epoch [141/300], Step [600/600], d_loss: 0.9264, g_loss: 1.9182, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.7762, g_loss: 1.7968, D(x): 0.78, D(G(z)): 0.32
# Epoch [142/300], Step [400/600], d_loss: 0.8247, g_loss: 1.7377, D(x): 0.70, D(G(z)): 0.28
# Epoch [142/300], Step [600/600], d_loss: 0.7268, g_loss: 1.5759, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.9953, g_loss: 1.8709, D(x): 0.67, D(G(z)): 0.31
# Epoch [143/300], Step [400/600], d_loss: 0.8571, g_loss: 1.4703, D(x): 0.74, D(G(z)): 0.34
# Epoch [143/300], Step [600/600], d_loss: 0.8047, g_loss: 1.4535, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.9724, g_loss: 1.9334, D(x): 0.69, D(G(z)): 0.29
# Epoch [144/300], Step [400/600], d_loss: 0.8877, g_loss: 2.1527, D(x): 0.69, D(G(z)): 0.25
# Epoch [144/300], Step [600/600], d_loss: 0.9925, g_loss: 1.5043, D(x): 0.73, D(G(z)): 0.35
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.9953, g_loss: 1.5268, D(x): 0.60, D(G(z)): 0.24
# Epoch [145/300], Step [400/600], d_loss: 1.0471, g_loss: 1.4238, D(x): 0.65, D(G(z)): 0.31
# Epoch [145/300], Step [600/600], d_loss: 0.9063, g_loss: 1.3835, D(x): 0.77, D(G(z)): 0.37
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.8493, g_loss: 1.6684, D(x): 0.72, D(G(z)): 0.28
# Epoch [146/300], Step [400/600], d_loss: 1.1398, g_loss: 1.2768, D(x): 0.71, D(G(z)): 0.41
# Epoch [146/300], Step [600/600], d_loss: 0.9588, g_loss: 1.6980, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.8466, g_loss: 1.5933, D(x): 0.77, D(G(z)): 0.30
# Epoch [147/300], Step [400/600], d_loss: 0.8461, g_loss: 1.6375, D(x): 0.76, D(G(z)): 0.32
# Epoch [147/300], Step [600/600], d_loss: 0.7642, g_loss: 2.1138, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.9718, g_loss: 2.2620, D(x): 0.64, D(G(z)): 0.21
# Epoch [148/300], Step [400/600], d_loss: 1.0768, g_loss: 1.3068, D(x): 0.73, D(G(z)): 0.38
# Epoch [148/300], Step [600/600], d_loss: 0.6848, g_loss: 1.8841, D(x): 0.84, D(G(z)): 0.29
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 1.1666, g_loss: 1.3139, D(x): 0.64, D(G(z)): 0.36
# Epoch [149/300], Step [400/600], d_loss: 1.1603, g_loss: 1.7632, D(x): 0.74, D(G(z)): 0.40
# Epoch [149/300], Step [600/600], d_loss: 0.9696, g_loss: 1.7153, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 1.0589, g_loss: 1.4121, D(x): 0.66, D(G(z)): 0.31
# Epoch [150/300], Step [400/600], d_loss: 1.0404, g_loss: 1.3307, D(x): 0.63, D(G(z)): 0.29
# Epoch [150/300], Step [600/600], d_loss: 0.8024, g_loss: 1.7996, D(x): 0.72, D(G(z)): 0.24
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 1.0495, g_loss: 1.4065, D(x): 0.59, D(G(z)): 0.26
# Epoch [151/300], Step [400/600], d_loss: 0.9043, g_loss: 1.4106, D(x): 0.73, D(G(z)): 0.35
# Epoch [151/300], Step [600/600], d_loss: 0.9412, g_loss: 1.4168, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.9730, g_loss: 1.4127, D(x): 0.74, D(G(z)): 0.38
# Epoch [152/300], Step [400/600], d_loss: 0.7380, g_loss: 1.7538, D(x): 0.75, D(G(z)): 0.26
# Epoch [152/300], Step [600/600], d_loss: 0.8665, g_loss: 1.4078, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.9804, g_loss: 1.2961, D(x): 0.72, D(G(z)): 0.36
# Epoch [153/300], Step [400/600], d_loss: 1.0056, g_loss: 1.7572, D(x): 0.59, D(G(z)): 0.22
# Epoch [153/300], Step [600/600], d_loss: 0.9391, g_loss: 1.1592, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.9054, g_loss: 1.1297, D(x): 0.65, D(G(z)): 0.27
# Epoch [154/300], Step [400/600], d_loss: 0.9149, g_loss: 1.7887, D(x): 0.76, D(G(z)): 0.32
# Epoch [154/300], Step [600/600], d_loss: 0.9795, g_loss: 1.2733, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.9463, g_loss: 1.5491, D(x): 0.67, D(G(z)): 0.28
# Epoch [155/300], Step [400/600], d_loss: 0.8571, g_loss: 1.6561, D(x): 0.74, D(G(z)): 0.31
# Epoch [155/300], Step [600/600], d_loss: 0.7566, g_loss: 2.2984, D(x): 0.65, D(G(z)): 0.17
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.8574, g_loss: 1.3903, D(x): 0.69, D(G(z)): 0.28
# Epoch [156/300], Step [400/600], d_loss: 0.9646, g_loss: 1.4081, D(x): 0.73, D(G(z)): 0.38
# Epoch [156/300], Step [600/600], d_loss: 0.9057, g_loss: 1.8718, D(x): 0.65, D(G(z)): 0.24
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.9050, g_loss: 1.8508, D(x): 0.62, D(G(z)): 0.24
# Epoch [157/300], Step [400/600], d_loss: 0.8314, g_loss: 2.0127, D(x): 0.73, D(G(z)): 0.28
# Epoch [157/300], Step [600/600], d_loss: 0.9393, g_loss: 1.3166, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 1.0821, g_loss: 1.4406, D(x): 0.70, D(G(z)): 0.40
# Epoch [158/300], Step [400/600], d_loss: 0.7855, g_loss: 1.6891, D(x): 0.72, D(G(z)): 0.26
# Epoch [158/300], Step [600/600], d_loss: 0.9111, g_loss: 1.4574, D(x): 0.75, D(G(z)): 0.34
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 1.0032, g_loss: 1.6771, D(x): 0.68, D(G(z)): 0.30
# Epoch [159/300], Step [400/600], d_loss: 0.9745, g_loss: 1.4548, D(x): 0.79, D(G(z)): 0.41
# Epoch [159/300], Step [600/600], d_loss: 0.9280, g_loss: 1.2427, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 1.0426, g_loss: 1.4962, D(x): 0.68, D(G(z)): 0.33
# ...
# Epoch [247/300], Step [400/600], d_loss: 1.0099, g_loss: 1.4142, D(x): 0.68, D(G(z)): 0.34
# Epoch [247/300], Step [600/600], d_loss: 0.9706, g_loss: 1.4713, D(x): 0.62, D(G(z)): 0.24
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 1.1065, g_loss: 1.8420, D(x): 0.60, D(G(z)): 0.27
# Epoch [248/300], Step [400/600], d_loss: 0.8621, g_loss: 1.8555, D(x): 0.70, D(G(z)): 0.28
# Epoch [248/300], Step [600/600], d_loss: 0.9753, g_loss: 1.5015, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 1.0894, g_loss: 1.1154, D(x): 0.66, D(G(z)): 0.38
# Epoch [249/300], Step [400/600], d_loss: 0.9285, g_loss: 1.4760, D(x): 0.70, D(G(z)): 0.32
# Epoch [249/300], Step [600/600], d_loss: 0.8266, g_loss: 1.4691, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 1.1289, g_loss: 1.5540, D(x): 0.59, D(G(z)): 0.31
# Epoch [250/300], Step [400/600], d_loss: 0.8583, g_loss: 1.4099, D(x): 0.73, D(G(z)): 0.33
# Epoch [250/300], Step [600/600], d_loss: 0.9753, g_loss: 1.4766, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.9683, g_loss: 1.8331, D(x): 0.62, D(G(z)): 0.26
# Epoch [251/300], Step [400/600], d_loss: 0.8827, g_loss: 1.6041, D(x): 0.74, D(G(z)): 0.35
# Epoch [251/300], Step [600/600], d_loss: 1.1885, g_loss: 1.1733, D(x): 0.69, D(G(z)): 0.40
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.9775, g_loss: 1.4679, D(x): 0.65, D(G(z)): 0.31
# Epoch [252/300], Step [400/600], d_loss: 0.8666, g_loss: 1.3930, D(x): 0.69, D(G(z)): 0.30
# Epoch [252/300], Step [600/600], d_loss: 1.0009, g_loss: 1.3772, D(x): 0.63, D(G(z)): 0.27
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 1.0102, g_loss: 1.2246, D(x): 0.66, D(G(z)): 0.32
# Epoch [253/300], Step [400/600], d_loss: 1.0764, g_loss: 1.4332, D(x): 0.71, D(G(z)): 0.38
# Epoch [253/300], Step [600/600], d_loss: 1.0399, g_loss: 1.8724, D(x): 0.62, D(G(z)): 0.28
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.9131, g_loss: 1.2254, D(x): 0.68, D(G(z)): 0.31
# Epoch [254/300], Step [400/600], d_loss: 0.8640, g_loss: 1.5883, D(x): 0.69, D(G(z)): 0.28
# Epoch [254/300], Step [600/600], d_loss: 1.0011, g_loss: 1.4420, D(x): 0.66, D(G(z)): 0.32
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.9548, g_loss: 1.7901, D(x): 0.62, D(G(z)): 0.26
# Epoch [255/300], Step [400/600], d_loss: 0.9339, g_loss: 1.5731, D(x): 0.68, D(G(z)): 0.28
# Epoch [255/300], Step [600/600], d_loss: 0.9955, g_loss: 1.5095, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.9122, g_loss: 1.4855, D(x): 0.72, D(G(z)): 0.33
# Epoch [256/300], Step [400/600], d_loss: 0.8210, g_loss: 1.5635, D(x): 0.68, D(G(z)): 0.24
# Epoch [256/300], Step [600/600], d_loss: 0.9255, g_loss: 1.5481, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9267, g_loss: 1.5315, D(x): 0.68, D(G(z)): 0.29
# Epoch [257/300], Step [400/600], d_loss: 0.9776, g_loss: 1.3780, D(x): 0.63, D(G(z)): 0.26
# Epoch [257/300], Step [600/600], d_loss: 0.7976, g_loss: 1.6836, D(x): 0.81, D(G(z)): 0.35
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 1.0100, g_loss: 1.3238, D(x): 0.65, D(G(z)): 0.30
# Epoch [258/300], Step [400/600], d_loss: 1.0350, g_loss: 1.2011, D(x): 0.70, D(G(z)): 0.36
# Epoch [258/300], Step [600/600], d_loss: 0.9018, g_loss: 1.5447, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.7852, g_loss: 1.4889, D(x): 0.71, D(G(z)): 0.26
# Epoch [259/300], Step [400/600], d_loss: 1.0875, g_loss: 1.2410, D(x): 0.63, D(G(z)): 0.34
# Epoch [259/300], Step [600/600], d_loss: 0.9690, g_loss: 1.5733, D(x): 0.62, D(G(z)): 0.28
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.9288, g_loss: 1.3420, D(x): 0.67, D(G(z)): 0.29
# Epoch [260/300], Step [400/600], d_loss: 0.8713, g_loss: 1.3916, D(x): 0.78, D(G(z)): 0.37
# Epoch [260/300], Step [600/600], d_loss: 0.9152, g_loss: 1.7847, D(x): 0.64, D(G(z)): 0.24
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.7327, g_loss: 1.6470, D(x): 0.76, D(G(z)): 0.28
# Epoch [261/300], Step [400/600], d_loss: 0.8015, g_loss: 1.4208, D(x): 0.74, D(G(z)): 0.31
# Epoch [261/300], Step [600/600], d_loss: 0.9044, g_loss: 1.5840, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.9693, g_loss: 1.4876, D(x): 0.64, D(G(z)): 0.25
# Epoch [262/300], Step [400/600], d_loss: 0.9067, g_loss: 1.6360, D(x): 0.66, D(G(z)): 0.28
# Epoch [262/300], Step [600/600], d_loss: 0.8458, g_loss: 1.3934, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.9073, g_loss: 1.2944, D(x): 0.66, D(G(z)): 0.30
# Epoch [263/300], Step [400/600], d_loss: 1.0787, g_loss: 1.0223, D(x): 0.71, D(G(z)): 0.42
# Epoch [263/300], Step [600/600], d_loss: 0.9527, g_loss: 1.3899, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.8604, g_loss: 1.6018, D(x): 0.73, D(G(z)): 0.31
# Epoch [264/300], Step [400/600], d_loss: 1.2203, g_loss: 1.6838, D(x): 0.63, D(G(z)): 0.38
# Epoch [264/300], Step [600/600], d_loss: 1.0171, g_loss: 1.2213, D(x): 0.78, D(G(z)): 0.41
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 1.0213, g_loss: 1.5568, D(x): 0.72, D(G(z)): 0.38
# Epoch [265/300], Step [400/600], d_loss: 1.0358, g_loss: 1.2897, D(x): 0.66, D(G(z)): 0.32
# Epoch [265/300], Step [600/600], d_loss: 0.9713, g_loss: 1.8116, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.9734, g_loss: 1.4627, D(x): 0.71, D(G(z)): 0.35
# Epoch [266/300], Step [400/600], d_loss: 0.9733, g_loss: 1.4517, D(x): 0.73, D(G(z)): 0.35
# Epoch [266/300], Step [600/600], d_loss: 0.8577, g_loss: 1.5935, D(x): 0.70, D(G(z)): 0.31
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.9242, g_loss: 1.1689, D(x): 0.81, D(G(z)): 0.43
# Epoch [267/300], Step [400/600], d_loss: 1.2919, g_loss: 1.7258, D(x): 0.66, D(G(z)): 0.40
# Epoch [267/300], Step [600/600], d_loss: 0.8589, g_loss: 1.5022, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.9827, g_loss: 1.4482, D(x): 0.65, D(G(z)): 0.28
# Epoch [268/300], Step [400/600], d_loss: 0.9566, g_loss: 1.0483, D(x): 0.69, D(G(z)): 0.33
# Epoch [268/300], Step [600/600], d_loss: 0.8787, g_loss: 1.9099, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.8990, g_loss: 1.4711, D(x): 0.66, D(G(z)): 0.27
# Epoch [269/300], Step [400/600], d_loss: 1.0459, g_loss: 1.3113, D(x): 0.69, D(G(z)): 0.39
# Epoch [269/300], Step [600/600], d_loss: 0.9419, g_loss: 1.4578, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.9957, g_loss: 1.3580, D(x): 0.62, D(G(z)): 0.27
# Epoch [270/300], Step [400/600], d_loss: 0.8772, g_loss: 1.2898, D(x): 0.68, D(G(z)): 0.28
# Epoch [270/300], Step [600/600], d_loss: 0.7929, g_loss: 1.8971, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.8765, g_loss: 1.5977, D(x): 0.77, D(G(z)): 0.36
# Epoch [271/300], Step [400/600], d_loss: 1.0003, g_loss: 1.6033, D(x): 0.65, D(G(z)): 0.25
# Epoch [271/300], Step [600/600], d_loss: 0.8198, g_loss: 1.5621, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 1.0569, g_loss: 1.4014, D(x): 0.66, D(G(z)): 0.35
# Epoch [272/300], Step [400/600], d_loss: 1.0099, g_loss: 1.6917, D(x): 0.68, D(G(z)): 0.31
# Epoch [272/300], Step [600/600], d_loss: 0.9432, g_loss: 1.3183, D(x): 0.74, D(G(z)): 0.36
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 1.0284, g_loss: 1.5495, D(x): 0.70, D(G(z)): 0.39
# Epoch [273/300], Step [400/600], d_loss: 0.9966, g_loss: 1.6655, D(x): 0.69, D(G(z)): 0.35
# Epoch [273/300], Step [600/600], d_loss: 0.8907, g_loss: 1.3948, D(x): 0.63, D(G(z)): 0.24
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.9145, g_loss: 1.5151, D(x): 0.69, D(G(z)): 0.32
# Epoch [274/300], Step [400/600], d_loss: 0.9291, g_loss: 1.4194, D(x): 0.68, D(G(z)): 0.32
# Epoch [274/300], Step [600/600], d_loss: 1.0208, g_loss: 1.2980, D(x): 0.61, D(G(z)): 0.26
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.9830, g_loss: 1.1440, D(x): 0.74, D(G(z)): 0.39
# Epoch [275/300], Step [400/600], d_loss: 0.8794, g_loss: 1.4386, D(x): 0.67, D(G(z)): 0.27
# Epoch [275/300], Step [600/600], d_loss: 0.8870, g_loss: 1.9754, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.9674, g_loss: 1.7061, D(x): 0.69, D(G(z)): 0.31
# Epoch [276/300], Step [400/600], d_loss: 0.8774, g_loss: 1.7559, D(x): 0.66, D(G(z)): 0.26
# Epoch [276/300], Step [600/600], d_loss: 0.9838, g_loss: 1.5621, D(x): 0.63, D(G(z)): 0.27
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.9391, g_loss: 1.7335, D(x): 0.61, D(G(z)): 0.23
# Epoch [277/300], Step [400/600], d_loss: 0.9996, g_loss: 1.0699, D(x): 0.71, D(G(z)): 0.38
# Epoch [277/300], Step [600/600], d_loss: 0.8815, g_loss: 1.2448, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.9597, g_loss: 1.4268, D(x): 0.69, D(G(z)): 0.35
# Epoch [278/300], Step [400/600], d_loss: 0.8914, g_loss: 1.4860, D(x): 0.76, D(G(z)): 0.37
# Epoch [278/300], Step [600/600], d_loss: 0.9751, g_loss: 1.5479, D(x): 0.72, D(G(z)): 0.38
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 1.0926, g_loss: 1.6143, D(x): 0.64, D(G(z)): 0.32
# Epoch [279/300], Step [400/600], d_loss: 1.0496, g_loss: 1.3277, D(x): 0.68, D(G(z)): 0.36
# Epoch [279/300], Step [600/600], d_loss: 0.9353, g_loss: 1.3740, D(x): 0.78, D(G(z)): 0.38
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.7730, g_loss: 1.6235, D(x): 0.78, D(G(z)): 0.32
# Epoch [280/300], Step [400/600], d_loss: 0.9869, g_loss: 1.4642, D(x): 0.67, D(G(z)): 0.32
# Epoch [280/300], Step [600/600], d_loss: 0.9064, g_loss: 1.3641, D(x): 0.74, D(G(z)): 0.35
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.9133, g_loss: 1.7685, D(x): 0.72, D(G(z)): 0.32
# Epoch [281/300], Step [400/600], d_loss: 1.0866, g_loss: 1.2408, D(x): 0.67, D(G(z)): 0.35
# Epoch [281/300], Step [600/600], d_loss: 0.9267, g_loss: 1.4162, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.9793, g_loss: 1.6601, D(x): 0.67, D(G(z)): 0.31
# Epoch [282/300], Step [400/600], d_loss: 0.8675, g_loss: 1.7396, D(x): 0.69, D(G(z)): 0.26
# Epoch [282/300], Step [600/600], d_loss: 0.8633, g_loss: 1.6901, D(x): 0.64, D(G(z)): 0.19
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.9115, g_loss: 1.0252, D(x): 0.73, D(G(z)): 0.35
# Epoch [283/300], Step [400/600], d_loss: 0.9084, g_loss: 1.5735, D(x): 0.71, D(G(z)): 0.33
# Epoch [283/300], Step [600/600], d_loss: 0.9248, g_loss: 1.8225, D(x): 0.64, D(G(z)): 0.26
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.8756, g_loss: 1.6788, D(x): 0.69, D(G(z)): 0.30
# Epoch [284/300], Step [400/600], d_loss: 0.9679, g_loss: 1.3963, D(x): 0.78, D(G(z)): 0.42
# Epoch [284/300], Step [600/600], d_loss: 0.8368, g_loss: 1.5500, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.9040, g_loss: 1.5271, D(x): 0.69, D(G(z)): 0.30
# Epoch [285/300], Step [400/600], d_loss: 0.9646, g_loss: 1.8526, D(x): 0.69, D(G(z)): 0.32
# Epoch [285/300], Step [600/600], d_loss: 0.8464, g_loss: 1.8178, D(x): 0.75, D(G(z)): 0.34
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.8468, g_loss: 1.5571, D(x): 0.70, D(G(z)): 0.27
# Epoch [286/300], Step [400/600], d_loss: 0.9786, g_loss: 1.2939, D(x): 0.73, D(G(z)): 0.36
# Epoch [286/300], Step [600/600], d_loss: 0.9316, g_loss: 1.9445, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.8762, g_loss: 1.3069, D(x): 0.67, D(G(z)): 0.27
# Epoch [287/300], Step [400/600], d_loss: 0.8863, g_loss: 1.4221, D(x): 0.76, D(G(z)): 0.36
# Epoch [287/300], Step [600/600], d_loss: 1.0595, g_loss: 1.6639, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.9350, g_loss: 1.5439, D(x): 0.69, D(G(z)): 0.32
# Epoch [288/300], Step [400/600], d_loss: 0.9598, g_loss: 1.2963, D(x): 0.73, D(G(z)): 0.34
# Epoch [288/300], Step [600/600], d_loss: 0.9679, g_loss: 1.7141, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 1.0055, g_loss: 1.3110, D(x): 0.73, D(G(z)): 0.36
# Epoch [289/300], Step [400/600], d_loss: 1.1427, g_loss: 1.2161, D(x): 0.65, D(G(z)): 0.34
# Epoch [289/300], Step [600/600], d_loss: 1.0713, g_loss: 1.7734, D(x): 0.58, D(G(z)): 0.26
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.8633, g_loss: 1.7074, D(x): 0.69, D(G(z)): 0.27
# Epoch [290/300], Step [400/600], d_loss: 0.9032, g_loss: 1.1275, D(x): 0.70, D(G(z)): 0.34
# Epoch [290/300], Step [600/600], d_loss: 0.9986, g_loss: 1.2651, D(x): 0.62, D(G(z)): 0.30
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.8099, g_loss: 1.5127, D(x): 0.72, D(G(z)): 0.27
# Epoch [291/300], Step [400/600], d_loss: 1.0223, g_loss: 1.5509, D(x): 0.63, D(G(z)): 0.29
# Epoch [291/300], Step [600/600], d_loss: 0.9362, g_loss: 1.6289, D(x): 0.62, D(G(z)): 0.24
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 1.0086, g_loss: 1.5569, D(x): 0.66, D(G(z)): 0.32
# Epoch [292/300], Step [400/600], d_loss: 0.9542, g_loss: 1.2432, D(x): 0.69, D(G(z)): 0.33
# Epoch [292/300], Step [600/600], d_loss: 0.8934, g_loss: 1.3205, D(x): 0.75, D(G(z)): 0.34
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.9521, g_loss: 1.8604, D(x): 0.70, D(G(z)): 0.32
# Epoch [293/300], Step [400/600], d_loss: 0.8841, g_loss: 1.8404, D(x): 0.65, D(G(z)): 0.23
# Epoch [293/300], Step [600/600], d_loss: 1.0155, g_loss: 1.6380, D(x): 0.65, D(G(z)): 0.32
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.9242, g_loss: 1.5132, D(x): 0.70, D(G(z)): 0.31
# Epoch [294/300], Step [400/600], d_loss: 1.1924, g_loss: 1.3694, D(x): 0.70, D(G(z)): 0.42
# Epoch [294/300], Step [600/600], d_loss: 0.9474, g_loss: 1.1098, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.9753, g_loss: 1.7793, D(x): 0.67, D(G(z)): 0.32
# Epoch [295/300], Step [400/600], d_loss: 0.8307, g_loss: 1.4409, D(x): 0.78, D(G(z)): 0.36
# Epoch [295/300], Step [600/600], d_loss: 0.9614, g_loss: 1.7585, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 1.0367, g_loss: 1.3104, D(x): 0.66, D(G(z)): 0.33
# Epoch [296/300], Step [400/600], d_loss: 0.8199, g_loss: 1.6696, D(x): 0.70, D(G(z)): 0.28
# Epoch [296/300], Step [600/600], d_loss: 0.9134, g_loss: 1.5304, D(x): 0.70, D(G(z)): 0.31
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 1.1436, g_loss: 1.7358, D(x): 0.63, D(G(z)): 0.32
# Epoch [297/300], Step [400/600], d_loss: 0.9686, g_loss: 1.5433, D(x): 0.70, D(G(z)): 0.33
# Epoch [297/300], Step [600/600], d_loss: 0.9508, g_loss: 1.4148, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 1.0329, g_loss: 1.3203, D(x): 0.73, D(G(z)): 0.38
# Epoch [298/300], Step [400/600], d_loss: 1.0233, g_loss: 1.5288, D(x): 0.69, D(G(z)): 0.37
# Epoch [298/300], Step [600/600], d_loss: 1.1144, g_loss: 1.2869, D(x): 0.66, D(G(z)): 0.38
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.8222, g_loss: 1.6729, D(x): 0.73, D(G(z)): 0.30
# Epoch [299/300], Step [400/600], d_loss: 0.7678, g_loss: 1.6665, D(x): 0.74, D(G(z)): 0.26
# Epoch [299/300], Step [600/600], d_loss: 0.8555, g_loss: 1.3017, D(x): 0.69, D(G(z)): 0.29
# Saving fake_images-0300.png
# CPU times: user 1h 2min 33s, sys: 43.4 s, total: 1h 3min 16s
# Wall time: 1h 3min 11s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# at first the discriminator can tell which is true and which is false . That's why the scores are very different. but as training goes on , the generator gets better and the two scores gets closer , when the two scores becomes the same, the training is complete and the  perfect generator because it can generate same images as real images
